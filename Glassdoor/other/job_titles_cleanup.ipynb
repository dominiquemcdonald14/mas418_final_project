# %%
import os
import csv
import pandas as pd
import numpy as np
import string

# %%
#would need to change working directory to the output folder prior to loading data 
os.getcwd()
os.chdir("./output")

# %%
df = pd.read_csv("output_.csv", encoding= 'unicode_escape')
df
# Out:
#                     companyName  company_starRating  \
# 0                       Epsilon                 3.9
# 1              Northrop Grumman                 4.0
# 2                Customers Bank                 4.3
# 3        MIT Lincoln Laboratory                 4.3
# 4     Ainsworth Game Technology                 2.8
# ..                          ...                 ...
# 85                 Pacific Life                 4.0
# 86          Knowli Data Science                 NaN
# 87                        Sappi                 3.8
# 88  Novateur Research Solutions                 NaN
# 89                     SoCalGas                 4.3
#
#                                   company_offeredRole company_roleLocation  \
# 0                                      Data Scientist           Irving, TX
# 1                             Data Management Analyst                Texas
# 2                                 Senior Data Analyst         Pennsylvania
# ...

# %%
job_title = df['company_offeredRole']
job_title = job_title.to_frame()
job_title
# Out:
#                                   company_offeredRole
# 0                                      Data Scientist
# 1                             Data Management Analyst
# 2                                 Senior Data Analyst
# 3   Business Manager- Artificial Intelligence Tech...
# 4                           Senior Game Mathematician
# ..                                                ...
# 85                           Senior Data Scientist II
# 86                    Data Scientist/Database Analyst
# 87                             Digital Data Scientist
# 88                         Machine Learning Scientist
# 89  Project Manager II -Data Science (Hybrid Sched...
#
# [90 rows x 1 columns]

# %%
job_title["Role"] = None #create empty column 
job_title["Role"][job_title["company_offeredRole"].str.contains("Data Scientist", case=False)] = "Data Scientist" #fill the column with phrases we're looking for
job_title["Role"][job_title["company_offeredRole"].str.contains("Data Analytics", case=False)] = "Data Analyst" #fill the column
job_title["Role"][job_title["company_offeredRole"].str.contains("Applied Scientist", case=False)] = "Machine Learning"
job_title["Role"][job_title["company_offeredRole"].str.contains("Data Engineer", case=False)] = "Data Engineer" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Software Engineer", case=False)] = "Others" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Data Integration", case=False)] = "Others" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Machine Learning", case=False)] = "Machine Learning" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Systems Engineer", case=False)] = "Others" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Business Analytics", case=False)] = "Data Analyst" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Statistician", case=False)] = "Data Scientist" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Data Science", case=False)] = "Data Scientist" 
job_title["Role"][job_title["company_offeredRole"].str.contains("Data Analyst", case=False)] = "Data Analyst" 

job_title
# Out:
#                                   company_offeredRole              Role
# 0                                      Data Scientist    Data Scientist
# 1                             Data Management Analyst              None
# 2                                 Senior Data Analyst      Data Analyst
# 3   Business Manager- Artificial Intelligence Tech...              None
# 4                           Senior Game Mathematician              None
# ..                                                ...               ...
# 85                           Senior Data Scientist II    Data Scientist
# 86                    Data Scientist/Database Analyst    Data Scientist
# 87                             Digital Data Scientist    Data Scientist
# 88                         Machine Learning Scientist  Machine Learning
# 89  Project Manager II -Data Science (Hybrid Sched...    Data Scientist
#
# [90 rows x 2 columns]

# %%
#if you want to save this as a csv file
#job_title.to_csv('job_titles.csv')
